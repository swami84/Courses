# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.erdos_renyi_graph(10, 0.5,seed=0)
pos = nx.circular_layout(G)
nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=700, font_size=10, font_color='black', font_weight='bold', edge_color='gray')

# %%
G = nx.erdos_renyi_graph(10, 0.1,seed=0)
pos = nx.circular_layout(G)
nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=700, font_size=10, font_color='black', font_weight='bold', edge_color='gray')

# %%
G = nx.erdos_renyi_graph(10, 0.9,seed=0)
pos = nx.circular_layout(G)
nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=700, font_size=10, font_color='black', font_weight='bold', edge_color='gray')

# %%
G = nx.gnm_random_graph(3, 2, seed=0)
pos = nx.circular_layout(G)
nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=700, font_size=10, font_color='black', font_weight='bold', edge_color='gray')

# %% [markdown]
# ## Small World Graph

# %%
G = nx.watts_strogatz_graph(10, 4, 0.5, seed=0)
pos = nx.circular_layout(G)
nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=700, font_size=10, font_color='black', font_weight='bold', edge_color='gray')

# %%
G = nx.watts_strogatz_graph(10, 4, 0.1, seed=0)
pos = nx.circular_layout(G)
nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=700, font_size=10, font_color='black', font_weight='bold', edge_color='gray')

# %%
G = nx.watts_strogatz_graph(10, 4, 1, seed=0)
pos = nx.circular_layout(G)
nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=700, font_size=10, font_color='black', font_weight='bold', edge_color='gray')
